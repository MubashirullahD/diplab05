# %%
import numpy as np
from PIL import Image
import cv2

# %% [markdown]
# # Task 1

# %% [markdown]
# ### Each image type needs to be handles differently

# %%
im = Image.open('lena_color.gif').convert('RGB')

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x46A60F0>

# %%
r, g, b = im.split()
r = r.point(lambda i : 255 - i)
g = g.point(lambda i : 255 - i)
b = b.point(lambda i : 255 - i)
imN = Image.merge('RGB', (r,g,b))
imN
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x478BFB0>

# %%
iml = Image.open('lena_color.gif').convert('L')
iml.save('lena_color.jpeg', 'JPEG')
ima = iml.point(lambda i : 255 - i)

# %%
iml
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x478BA10>

# %%
ima
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x478BA50>

# %%
imb = Image.open('lena_color.gif').convert('1')
ima2 = imb.point(lambda i : 0 if i else 255)

# %%
imb
# Out:
# <PIL.Image.Image image mode=1 size=512x512 at 0x478BBD0>

# %%
ima2
# Out:
# <PIL.Image.Image image mode=1 size=512x512 at 0x478BBB0>

# %% [markdown]
# ##### A function can be made. We would have to check image.shape. With it, if they were 3, use the RGB code, else do Binary and grey scale. The same code can be used.

# %% [markdown]
# # Task 2

# %%
img = cv2.imread('lena_color.jpeg', 2)
width, height = img.shape

# %%
# To change to other types, use img.astype(np.uint8) so calculations can go negative
img = img.astype(np.float16) # BEWARE! Use float not int16.

# %%
for y in range(height):
    # We skip the last column hence the - 1
    for x in range(1, width - 1):
        img[x][y] = (img[x + 1][y]) - (img[x][y]) 

bmax = np.amax(img)
bmin = np.amin(img)

# %%
img = (img - bmin)/abs(bmax - bmin) * 255
img = img.astype(np.uint8)

# %%
Image.fromarray(img, 'L')
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x97AE690>

# %% [markdown]
# ###### ideally you should use a different numpy array. With it, you will be able to use the other equation. x+1 - x-1

# %% [markdown]
# ### Task 3

# %%
dollar = cv2.imread('dollar.tif', 2)

# %%
y = 7
bit1 = dollar << y
Image.fromarray(bit1, 'L')
# Out:
# <PIL.Image.Image image mode=L size=1192x500 at 0x4B14950>

# %%
y = 6
bit2 = dollar << y
Image.fromarray(bit2, 'L')
# Out:
# <PIL.Image.Image image mode=L size=1192x500 at 0xE213270>

# %%
y = 5
bit3 = dollar << y
Image.fromarray(bit3, 'L')
# Out:
# <PIL.Image.Image image mode=L size=1192x500 at 0xE2130D0>

# %%
y = 4
bit4 = dollar << y
Image.fromarray(bit4, 'L')
# Out:
# <PIL.Image.Image image mode=L size=1192x500 at 0x4B142B0>

# %%
y = 3
bit5 = dollar << y
Image.fromarray(bit5, 'L')
# Out:
# <PIL.Image.Image image mode=L size=1192x500 at 0xE213070>

# %%
y = 2
bit6 = dollar << y
Image.fromarray(bit6, 'L')
# Out:
# <PIL.Image.Image image mode=L size=1192x500 at 0xE213030>

# %%
y = 1
bit7 = dollar << y
Image.fromarray(bit7, 'L')
# Out:
# <PIL.Image.Image image mode=L size=1192x500 at 0x4BAB150>

# %%
# Only the MSB
y = 7
bit7 = dollar >> y
bit7 = bit7   << y
Image.fromarray(bit7, 'L')
# Out:
# <PIL.Image.Image image mode=L size=1192x500 at 0x4BAB770>
